# %%
print("Hello World")

# %% [markdown]
# Websrapping
# 1. Check if the data is accessible
# 2. Get raw data in HTML
# 3. Get text data as a whole
# 4. Filter dats to displayspecificdata e.g quotes title, author values
# 5. Access data with HTML different selectors and tags
# 6. Save data to CSV file
# 7. Get data from all pages
# 8. Save data from all pages to CSV
# 9. Scrape data using selenium automation tool
